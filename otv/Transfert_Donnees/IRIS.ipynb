# %% [markdown]
# # IMPORTATION DES DONNEES DANS IRIS

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
import csv, os, re
import sys #c'est pas propre mais pour le moment pour importer mes modules perso dans le notebook je ne sais pas faire
sys.path.append(r'C:\Users\martin.schoreisz\git\Outils\Outils\Martin_Perso')
import Connexion_Transfert as ct

# %% [markdown]
# ## 1. IMPORTATION DES DONNEES GESTIONNAIRES TYPE T6 / B6
# > Exemple du CD16

# %% [markdown]
# ### 1.1 Ouverture des données de stations issues de IRIS

# %%
#ouvertur de la liste des stations
with open(r'P:\DAIT\TI\Donnees\1-ROUTIER\Logiciel-IRIS\Liste_des_stations_2019-17-06.csv', newline='') as f :
    freader=csv.reader(f, delimiter=';')
    liste=[]
    for indice,row in enumerate(freader) : 
        if indice==0 : 
            liste.append([re.sub(('é|è|ê'),'e',mot).replace('.','').replace(' ','_') for mot in row])
        else : 
            liste.append([re.sub(('é|è|ê'),'e',mot) for mot in row])
    df_station=pd.DataFrame(liste[1:], columns=liste[0])
    df_station=df_station.loc[df_station.Dep.isin(['16','17','79','86','33','24','40','47','64','23','19','87'])]

# %%
#mettre en forme les attributs pour comparaison : passer les lat,long et Prs station en float pour povoir comparer plus facilement (sans pb d'arrondi)
df_station['long']=df_station.apply(lambda x : float(x['Longitude']),axis=1)
df_station['Lat']=df_station.apply(lambda x : float(x['Latitude']),axis=1)
df_station['pr']=df_station.apply(lambda x : float(x['Pr_station'].split('.')[0]),axis=1)
df_station['abs']=df_station.apply(lambda x : float(x['Pr_station'].split('.')[1]),axis=1)
df_station['dep']=df_station.apply(lambda x : int(x['Dep']),axis=1)
df_station['route']=df_station.apply(lambda x : x['Routes'].replace(' ',''),axis=1)

# %%
#verifier les stations en doublons
df_station.sort_values('Id_reel').loc[df_station.duplicated('Id_reel',False)]
# Out:
#         Id            Id_reel Dep   Routes                 Nom Type  Sens_1  \
# 1487   541    24_RD_15_32.000  24     D 15       24 D15 32.0 T    T  Sens 1
# 1473  2351    24_RD_15_32.000  24     D 15         24-D15-32.0    T  Sens 1
# 2856  2353    24_RD_19_10.000  24     D 19         24-D19-10.0   Po  Sens 1
# 2866   542    24_RD_19_10.000  24     D 19      24 D19 10.0 Po   Po  Sens 1
# 2934  2355     24_RD_2_38.000  24      D 2          24-D2-38.0   Po  Sens 1
# 2944  1257     24_RD_2_38.000  24      D 2       24 D2 38.0 Po   Po  Sens 1
# 2932  2356     24_RD_2_41.000  24      D 2          24-D2-41.0    T  Sens 1
# 2953   548     24_RD_2_41.000  24      D 2        24 D2 41.0 T    T  Sens 1
# 2952   544     24_RD_2_53.000  24      D 2        24 D2 53.0 T    T  Sens 1
# 2933  2357     24_RD_2_53.000  24      D 2          24-D2-53.0    T  Sens 1
# 2951   545     24_RD_2_70.000  24      D 2        24 D2 70.0 T    T  Sens 1
# ...

# %% [markdown]
# ### 1.2 Test des fichiers

# %%
#pour chaque fichier on vérifie que les données de station sont connues, complete et que les fichiers de sens 1 et 2 sont dispos
chemin_src=r'P:\DAIT\TI\Donnees\1-ROUTIER\Logiciel-IRIS\CG16\2017_CD16\donnees_source\B6_IRIS_2017' # dossier contenant les données sources
chemin_dst=r'P:\DAIT\TI\Donnees\1-ROUTIER\Logiciel-IRIS\CG16\2017_CD16\pour_transfert_IRIS' #dossier allant contenir les données en forme
dico_recherche={'TV01':['TV02', 'PL01', 'PL02'],'TV02':['TV01', 'PL01', 'PL02'],'PL01':['TV02', 'TV01', 'PL02'], 'PL02':['TV02', 'TV01', 'PL01']} #pour tests tout fihciers dispo
for root, dir, files in os.walk(chemin_src) : 
    for file in files: 
        if file.endswith('.csv') : #on e s'interesse qu'au csv
            for value in dico_recherche[file[-8:-4]] : #on vérifie que tous les fihciers sont présents pour chauqe station sinon on print un message d'erreur
                if not os.path.isfile(os.path.join(chemin_src,file.replace(file[-8:-4],value))) : 
                    print(f'pas de sens {value[-1]} {value[:2]} pour {file}')
                    continue
            with open(os.path.join(chemin_src,file), newline='') as compt :
                compt_reader=csv.reader(compt, delimiter=';')
                dico={indice:row for indice,row in enumerate(compt_reader)} 
                voie=dico[4][16]    
                pr=dico[5][16].replace('+','.')
                dep=16
                type_voie='RD'
                dico[4][15]=type_voie   
                nom_reel='_'.join([str(dep),type_voie,voie,pr])
                df_cpt=pd.DataFrame(data=[dico[key][1:] for key in range(11,len(dico)-11)],
                                   index=[dico[key][0] for key in range(11,len(dico)-11)],
                                  columns=dico[10][1:])
                if nom_reel in df_station.Id_reel.tolist()  : #si le fichier est dans la liste des stations
                    if df_cpt.loc[df_cpt.isna().any(axis=1)].empty : #si pas de pb de données vide
                        with open(os.path.join(chemin_dst,file), 'w', newline='') as fichier_dst :
                            fichier_dst_writer=csv.writer(fichier_dst, delimiter=';')
                            for values in dico.values() : 
                                fichier_dst_writer.writerow(values)
                    else : 
                        print(f'pb donnees sur {file}')
                else : 
                    print(f'pb reference station sur {file}')

# %% [markdown]
# Une fois la liste des fichierssans station connue, il fauit créer les stations. <br> Si des fichiers présentent des trous dans les données il convient de les traiter. Pour cela, s'appuyer sur la doc de pandas __https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html__ ou sur le travail produit lors des RST ANalytics __https://github.com/PCAubin/DGITM/blob/master/RSTAnalytics%20-%20Donn%C3%A9es%20manquantes%20DGITM.ipynb__

# %% [markdown]
# # 2 Import des données de l'observatoire des trafics
# > L'idée est de créer un fichier qui réponde au format présenté au chapitre 5.3 de l'aide administrateur de IRIS __https://dreal.applis-bretagne.fr/iris/www/administration/FilesUploaded/pdf_admin/Notice-Administrateur.pdf__<br> Pour ça, j'import les données 2017 depuis la Bdd et j'ajoute des attributs, ensuite je fais 4 jointures successives pour obtenir d'un coté les références au station issues de IRIS et de l'autre les trafics, puis mise en forme selon la doc

# %%
with ct.ConnexionBdd('gti_otv') as c :
    requete='''
    select 
    replace(id_comptag,'+','.') as nom_station_bdd, type_poste, dep::integer as dep_bdd, reseau, route as route_bdd, pr as pr_bdd,abs as abs_bdd,
    st_y(st_transform(st_setsrid((st_dump(geom)).geom,2154),4326))  as "Latitude_station",
    st_x(st_transform(st_setsrid((st_dump(geom)).geom,2154),4326)) as "Longitude_station",
    'sens1'as sens1,'sens2'as sens2, 2017 as annee, 
    round((tmja_2017*(1-(pc_pl_2017*0.01)))/2)::integer as vl_sens_1, round(tmja_2017*pc_pl_2017/200)::integer as pl_sens_1, 
    round((tmja_2017*(1-(pc_pl_2017*0.01)))/2)::integer as vl_sens_2 , round(tmja_2017*pc_pl_2017/200)::integer as pl_sens_2
    from comptage.na_2010_2017_p
    where concession = 'N'
    '''
    df_tmja_otv=pd.read_sql_query(requete, c.sqlAlchemyConn)

# %%
#ne conserver que les lignes pour lesquelles l'ensembles des données est renseignées
df_tmja_otv_valide=df_tmja_otv.loc[df_tmja_otv.notna().all(axis=1)].copy()
#creer des attributs de jointure
df_tmja_otv_valide['Id_reel_bdd']=df_tmja_otv_valide.apply(lambda x : str(x['dep_bdd'])+'_'+x['reseau']+'_'+x['route_bdd'][1:]+'_'+x['nom_station_bdd']
                                                           .split('-')[2],axis=1)

# %%
# 1. jointure sur les dep, route,pr, abs
jointur_pr_abs=df_station.merge(df_tmja_otv_valide, left_on=['dep','route','pr','abs'], right_on=['dep_bdd','route_bdd','pr_bdd','abs_bdd'])
station_non_renseigne=df_station.loc[~df_station.Id.isin(jointur_pr_abs.Id.tolist())]
df_tmja_otv_valide_nr=df_tmja_otv_valide.loc[~df_tmja_otv_valide['nom_station_bdd'].isin(jointur_pr_abs.nom_station_bdd.tolist())].copy()

# %%
# 2. jointure sur coordonnees
jointure_coord=station_non_renseigne.merge(df_tmja_otv_valide_nr, left_on=['Lat','long'], right_on=['Latitude_station','Longitude_station'])
jointure_totale=pd.concat([jointur_pr_abs,jointure_coord],sort=False)
station_non_renseigne=df_station.loc[~df_station.Id.isin(jointure_totale.Id.tolist())]
df_tmja_otv_valide_nr=df_tmja_otv_valide.loc[~df_tmja_otv_valide['nom_station_bdd'].isin(jointure_totale.nom_station_bdd.tolist())].copy()

# %%
# 3.jointure sur id_reel
jointure_idreel=station_non_renseigne.merge(df_tmja_otv_valide_nr, left_on='Id_reel', right_on='Id_reel_bdd')
jointure_totale=pd.concat([jointure_totale,jointure_idreel],sort=False)
station_non_renseigne=df_station.loc[~df_station.Id.isin(jointure_totale.Id.tolist())]
df_tmja_otv_valide_nr=df_tmja_otv_valide.loc[~df_tmja_otv_valide['nom_station_bdd'].isin(jointure_totale.nom_station_bdd.tolist())].copy()

# %%
# 4. jointure sur abscisse proche
jointur_abs_proche=station_non_renseigne.merge(df_tmja_otv_valide_nr, left_on=['dep','route','pr'], right_on=['dep_bdd','route_bdd','pr_bdd'])
jointur_abs_proche_vf=jointur_abs_proche.loc[jointur_abs_proche.apply(lambda x : x['abs_bdd']-20<x['abs']<x['abs_bdd']+20, axis=1)].copy()
jointure_totale=pd.concat([jointure_totale,jointur_abs_proche_vf],sort=False)
station_non_renseigne=df_station.loc[~df_station.Id.isin(jointure_totale.Id.tolist())]
df_tmja_otv_valide_nr=df_tmja_otv_valide.loc[~df_tmja_otv_valide['nom_station_bdd'].isin(jointure_totale.nom_station_bdd.tolist())].copy()

# %%
# mettre en forme pour export csv : mise en form des données jointes puis celle non jointes, puis concat puis export
Fichier_export=jointure_totale.copy()
Fichier_export['Type de route']=Fichier_export.apply(lambda x : x['Routes'].split(' ')[0], axis=1)
Fichier_export['NjRoute']=Fichier_export.apply(lambda x : x['Routes'].split(' ')[1], axis=1)
Fichier_export.drop(['Id', 'Id_reel','Routes','Pr_origine_section', 'Lat_origine_section', 'Long_origine_section', 'Pr_fin_section',
       'Lat_fin_section', 'Long_fin_section', 'Date_prise_effet', 'long','Lat', 'pr', 'abs', 'dep', 'route', 'nom_station_bdd', 'type_poste',
       'dep_bdd', 'reseau', 'route_bdd', 'pr_bdd', 'abs_bdd', 'Latitude_station', 'Longitude_station', 'sens1', 'sens2', 'Id_reel_bdd'],axis=1, inplace=True)
Fichier_export.rename(columns={'Nom':'Nom Station','Type':'Type Station', 'Dep':'Département', 'Pr_station':'PR Station',
                              'Latitude':'Latitude_station','Longitude':'Longitude_station'}, inplace=True)
Fichier_export=Fichier_export[['Nom Station','Type Station','Département','Type de route','NjRoute','PR Station','Latitude_station','Longitude_station','Sens_1','Sens_2',
               'annee', 'vl_sens_1', 'pl_sens_1', 'vl_sens_2','pl_sens_2']]
Fichier_export=Fichier_export.reset_index().reset_index().drop('index',axis=1)
Fichier_export['index_f']=Fichier_export.apply(lambda x : x['level_0']+2,axis=1)
Fichier_export.drop('level_0',axis=1, inplace = True)
Fichier_export.set_index('index_f', inplace=True)
for i in ['annee','vl_sens_1','pl_sens_1','vl_sens_2','pl_sens_2'] : 
    Fichier_export[i]=Fichier_export.apply(lambda x : int(x[i]),axis=1)
Fichier_export.loc[0]=np.NaN
Fichier_export.loc[1]=np.NaN
Fichier_export.sort_index(inplace=True)
for i in ['annee','vl_sens_1','pl_sens_1','vl_sens_2','pl_sens_2'] : 
    Fichier_export[i]=pd.array(Fichier_export[i].tolist(),dtype=pd.Int64Dtype())
    
def type_station(type_s):
    if type_s=='tournant' : 
        return 'T'
    elif type_s=='ponctuel' : 
        return 'Po'
    elif type_s=='permanent' : 
        return 'P'

df_tmja_otv_valide_nr['PR Station']=df_tmja_otv_valide_nr.apply(lambda x : str(round(x['pr_bdd']))+'.'+"{:03d}".format(int(x['abs_bdd'])),axis=1)
df_tmja_otv_valide_nr['Id_reel_bdd']=df_tmja_otv_valide_nr.apply(lambda x : str(x['dep_bdd'])+'_'+x['reseau']+'_'+x['route_bdd'][1:]+'_'+x['PR Station'],axis=1)
df_tmja_otv_valide_nr['nom_station_bdd']=df_tmja_otv_valide_nr.apply(lambda x : '-'.join(x['nom_station_bdd'].split('-')[:2])+x['PR Station'],axis=1)
df_tmja_otv_valide_nr['type_poste']=df_tmja_otv_valide_nr.apply(lambda x : type_station(x['type_poste']), axis=1)
df_tmja_otv_valide_nr['reseau']=df_tmja_otv_valide_nr.apply(lambda x : x['reseau'][-1], axis=1)
df_tmja_otv_valide_nr['NjRoute']=df_tmja_otv_valide_nr.apply(lambda x : int(re.search('([A-Z])([0-9]{1,4})',x['route_bdd']).group(2)),axis=1)
df_tmja_otv_valide_nr.rename(columns={'nom_station_bdd':'Nom Station','type_poste':'Type Station','dep_bdd':'Département','reseau':'Type de route',
                                      'y_wgs':'Latitude station','x_wgs':'Longitude station','sens1':'Sens_1', 'sens2':'Sens_2'}, inplace=True)
df_tmja_otv_valide_nr.drop(['route_bdd', 'pr_bdd', 'abs_bdd','Id_reel_bdd'],axis=1, inplace=True)
df_tmja_otv_valide_nr=df_tmja_otv_valide_nr[['Nom Station','Type Station','Département','Type de route','NjRoute','PR Station','Latitude_station','Longitude_station','Sens_1','Sens_2',
               'annee', 'vl_sens_1', 'pl_sens_1', 'vl_sens_2','pl_sens_2']]
for i in ['annee','vl_sens_1','pl_sens_1','vl_sens_2','pl_sens_2'] : 
    df_tmja_otv_valide_nr[i]=df_tmja_otv_valide_nr.apply(lambda x : int(x[i]),axis=1)
    
pd.concat([Fichier_export,df_tmja_otv_valide_nr],sort=False).to_csv(r'Q:\DAIT\TI\DREAL33\2019\C19SA0035_OTR-NA\GT_donnees_mobilite_collectivites\insertion_donnees_iris\exemple_fichier_tmja.csv',sep=';',
                     index=False)
