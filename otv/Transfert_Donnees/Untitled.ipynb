# %% [markdown]
# # Import des données CD40 dans gti_otv

# %%
import sys
sys.path.append(r'C:\Users\martin.schoreisz\git\otv\otv\Transfert_Donnees')
sys.path.append(r'C:\Users\martin.schoreisz\git\Outils\Outils\Martin_Perso')
import cd40
# Out:
# Q:\DAIT\TI\DREAL33\2019\C19SA0035_OTR-NA\Doc_travail\Donnees_source\CD40\Trafics 2018 Landes\comptage_B152\ST_AVIT\040.2020.00\B152 2018 TV.xls
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1215                     self.dialect.do_executemany(
# -> 1216                         cursor, statement, parameters, context
#    1217                     )
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     718         else:
# --> 719             cursor.executemany(statement, parameters)
#     720
#
# IntegrityError: ERREUR:  la valeur d'une clé dupliquée rompt la contrainte unique « na_2010_2017_mensuel_pk »
# DETAIL:  La clé « (id_comptag, donnees_type, annee)=(40-D932-34+900, tmja, 2018) » existe déjà.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-3-390f94b37dff> in <module>
#       2 sys.path.append(r'C:\Users\martin.schoreisz\git\otv\otv\Transfert_Donnees')
#       3 sys.path.append(r'C:\Users\martin.schoreisz\git\Outils\Outils\Martin_Perso')
# ----> 4 import cd40
#
# ~\git\otv\otv\Transfert_Donnees\cd40.py in <module>
#      61                     c.curs.execute("insert into comptage.na_2010_2017_p (id_comptag, dep, route, pr, abs, reseau, gestionnai, concession,type_poste, id_cpt, ann_cpt, tmja_2018, pc_pl_2018) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",(id_comptag,dep,voie,pr,absice,reseau,gest,concession,type_poste,compteur,annee_cpt, tmja, pc_pl))
#      62                 c.connexionPsy.commit()
# ---> 63                 donnees.to_sql('na_2010_2017_mensuel', c.sqlAlchemyConn,schema='comptage',if_exists='append',index=False)
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     978             raise exc.ObjectNotExecutableError(object_)
#     979         else:
# --> 980             return meth(self, multiparams, params)
#     981
#     982     def _execute_function(self, func, multiparams, params):
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1097             distilled_params,
#    1098             compiled_sql,
# -> 1099             distilled_params,
#    1100         )
#    1101         if self._has_events or self.engine._has_events:
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1238         except BaseException as e:
#    1239             self._handle_dbapi_exception(
# -> 1240                 e, statement, parameters, cursor, context
#    1241             )
#    1242
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1456                 util.raise_from_cause(newraise, exc_info)
#    1457             elif should_wrap:
# -> 1458                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1459             else:
#    1460                 util.reraise(*exc_info)
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1214                 if not evt_handled:
#    1215                     self.dialect.do_executemany(
# -> 1216                         cursor, statement, parameters, context
#    1217                     )
#    1218             elif not parameters and context.no_parameters:
#
# c:\users\martin.schoreisz\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     717             extras.execute_batch(cursor, statement, parameters)
#     718         else:
# --> 719             cursor.executemany(statement, parameters)
#     720
#     721     @util.memoized_instancemethod
#
# IntegrityError: (psycopg2.IntegrityError) ERREUR:  la valeur d'une clé dupliquée rompt la contrainte unique « na_2010_2017_mensuel_pk »
# DETAIL:  La clé « (id_comptag, donnees_type, annee)=(40-D932-34+900, tmja, 2018) » existe déjà.
#  [SQL: 'INSERT INTO comptage.na_2010_2017_mensuel (id_comptag, donnees_type, annee, janv, fevr, mars, avri, mai, juin, juil, aout, sept, octo, nove, dece) VALUES (%(id_comptag)s, %(donnees_type)s, %(annee)s, %(janv)s, %(fevr)s, %(mars)s, %(avri)s, %(mai)s, %(juin)s, %(juil)s, %(aout)s, %(sept)s, %(octo)s, %(nove)s, %(dece)s)'] [parameters: ({'id_comptag': '40-D932-34+900', 'donnees_type': 'tmja', 'annee': '2018', 'janv': 12251.0, 'fevr': 12518.0, 'mars': 13477.0, 'avri': 14117.0, 'mai': 14233.0, 'juin': 13928.0, 'juil': 15690.0, 'aout': 15758.0, 'sept': 14662.0, 'octo': 14271.0, 'nove': 13013.0, 'dece': 12631.0}, {'id_comptag': '40-D932-34+900', 'donnees_type': 'pc_pl', 'annee': '2018', 'janv': 12.499045502539621, 'fevr': 13.104558007897198, 'mars': 12.881683728790028, 'avri': 13.229675804585488, 'mai': 13.49929627421961, 'juin': 11.48023166762397, 'juil': 11.930343962663706, 'aout': 10.994517889530766, 'sept': 12.385531760105488, 'octo': 13.282293665701477, 'nove': 13.273649427495581, 'dece': 11.356085003358354})] (Background on this error at: http://sqlalche.me/e/gkpj)
